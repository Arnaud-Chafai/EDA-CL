# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
from selenium import webdriver

# URL de la página
url = "https://www.eia.gov/todayinenergy/index.php?tg=crude%20oil"

# Obtener el contenido HTML de la página
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# Extraer los artículos y fechas
articulos = []
articulos_html = soup.select("div.tie-article.tag-view > h2 > a")  # Selector para los títulos de artículos
fechas_html = soup.select("div.tie-article.tag-view > span")  # Selector más general para las fechas

# Iterar sobre los elementos capturados
for articulo, fecha in zip(articulos_html, fechas_html):
    texto = articulo.get_text(strip=True)
    fecha_texto = fecha.get_text(strip=True)

    # Agregar al resultado
    articulos.append({
        'fechas': fecha_texto,
        'Noticia_EIA': texto
    })

# Convertir los resultados en un DataFrame
df = pd.DataFrame(articulos)

#Convertimos la fecha a formato datetime
df['fechas_noticia_EIA'] = pd.to_datetime(df['fechas'])
df.drop(columns="fechas",inplace=True)

# Guardar en CSV
df.to_csv('eia_today_in_energy_with_corrected_dates.csv', index=False)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_21424\1799367000.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df
# Out:
#                                            Noticia_EIA fechas_noticia_EIA
# 0    U.S. gasoline prices heading into Labor Day we...         2024-08-29
# 1    Permian production forecast growth driven by w...         2024-08-21
# 2    Public company proved oil and natural gas rese...         2024-08-12
# 3    Canada's crude oil has an increasingly signifi...         2024-08-01
# 4    Energy trade value between Mexico and the Unit...         2024-07-15
# ..                                                 ...                ...
# 609  Maritime chokepoints critical to petroleum mar...         2011-03-02
# 610  Gasoline prices — second largest one-week incr...         2011-03-01
# 611  WTI-Brent crude oil price spread has reached u...         2011-02-28
# 612  Gasoline product supplied may reflect snowstor...         2011-02-24
# 613  U.S. gasoline exports hit all-time high in Nov...         2011-02-22
#
# [614 rows x 2 columns]
